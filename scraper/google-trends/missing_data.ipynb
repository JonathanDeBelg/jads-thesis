# %%
from pytrends.request import TrendReq
import pandas as pd
import time

data = pd.read_csv('../../data/google-trends/missing_trends_data.csv')
player_names = data['Player Name'].unique().tolist()

# %%
def fetch_interest_over_time(player_name):
    try:
        pytrends.build_payload([player_name], timeframe='2023-03-01 2024-06-01')
        interest = pytrends.interest_over_time()
        if not interest.empty:
            interest.drop(columns=['isPartial'], inplace=True)
            interest.rename(columns={player_name: player_name.replace(" ", "_")}, inplace=True)
            return interest
    except Exception as e:
        print(f"Error fetching data for {player_name}: {str(e)}")
    return pd.DataFrame()

# %%
interest_data_frames = []
requested_players = []

# %%
for name in player_names:
    print(f"Fetching data for {name}")
    interest_df = fetch_interest_over_time(name)
    if not interest_df.empty:
        interest_data_frames.append(interest_df)
# Out:
# Fetching data for Paxten Aaronson
# Fetching data for Chuba Akpom
# Fetching data for Hamdi Akujobi
# Fetching data for Hussein Ali
# Fetching data for Joey Antonioli
# Fetching data for Anouar El Azzouzi
# Fetching data for Youri Baas
# Fetching data for Isaac Babadi
# Fetching data for Thibo Baeten
# Fetching data for Zakaria Bakkali
# Fetching data for Nordin Bakker
# Fetching data for Sven van Beek
# Fetching data for Thomas Beelen
# Fetching data for Benaissa Benamar
# Fetching data for Walter Benitez
# Fetching data for Gijs Besselink
# Fetching data for Justin Bijlow
# Fetching data for Yvandro Borges Sanches
# Fetching data for Olivier Boscagli
# Fetching data for Amine Boutrah
# Fetching data for Can Bozdogan
# Fetching data for Michael Brouwer
# Fetching data for Luuk Brouwers
# Fetching data for Damian van Bruggen
# Fetching data for Jordy Bruijn
# Fetching data for Jeffrey Bruma
# Fetching data for Max Bruns
# Fetching data for Thomas Buitink
# Fetching data for Yoann Cathline
# Fetching data for Milan Corryn
# Fetching data for Tiago Dantas
# Fetching data for Mickey van der Hart
# Fetching data for Toni Domgjoni
# Fetching data for Achraf Douiri
# Fetching data for Couhaib Driouech
# Fetching data for Mike van Duinen
# Fetching data for Mike Eerdhuijzen
# Fetching data for Mario Engels
# Fetching data for Luca Everink
# Fetching data for Ryan Flamingo
# Fetching data for Stijn van Gassel
# Fetching data for Lutsharel Geertruida
# Fetching data for Santiago Gimenez
# Fetching data for Marco van Ginkel
# Fetching data for Jay Gorter
# Fetching data for Kenzo Goudmijn
# Fetching data for Anis Hadj Moussa
# Fetching data for Denzel Hall
# Fetching data for Sontje Hansen
# Fetching data for Lennard Hartjes
# Fetching data for Mike Hauptmeijer
# Fetching data for Thom Haye
# Fetching data for Jordan Henderson
# Fetching data for Mees Hoedemakers
# Fetching data for Jizz Hornkamp
# Fetching data for Younes Taha El Idrissi
# Fetching data for Joey Jacobs
# Fetching data for Alireza Jahanbakhsh
# Fetching data for Darius Johnson
# Fetching data for Miliano Jonathans
# Fetching data for Luuk de Jong
# Fetching data for Denso Kasius
# Fetching data for Luuk Koopmans
# Fetching data for Peer Koopmeiners
# Fetching data for Joris Kramer
# Fetching data for Michiel Kramer
# Fetching data for Filip Krastev
# Fetching data for Zakaria Labyad
# Fetching data for Thomas Lam
# Fetching data for Luke Le Roux
# Fetching data for Kelvin Leerdam
# Fetching data for Marcos Lopez
# Fetching data for Faiz Mattoir
# Fetching data for Jakov Medic
# Fetching data for Younes Namli
# Fetching data for Noah Naujoks
# Fetching data for Bart Nieuwkoop
# Fetching data for Djenahro Nunumete
# Fetching data for Bram Nuytinck
# Fetching data for Ragnar Oratmangoen
# Fetching data for Yassin Oukili
# Fetching data for Vangelis Pavlidis
# Fetching data for Ricardo Pepi
# Fetching data for Kik Pierie
# Fetching data for Ivo Pinto
# Fetching data for Brian Plat
# Fetching data for Dirk Proper
# Fetching data for Gyan de Regt
# Fetching data for Stije Resink
# Fetching data for Julian Rijkhoff
# Fetching data for Thomas Robinet
# Fetching data for Robin Roefs
# Fetching data for Philippe Rommens
# Fetching data for Bart van Rooij
# Fetching data for Eloy Room
# Fetching data for Ruben Roosken
# Fetching data for Loreintz Rosier
# Fetching data for Daan Rots
# Fetching data for Mats Rots
# Fetching data for Ismael Saibari
# Fetching data for Cisse Sandra
# Fetching data for Mohamed Sankoh
# Fetching data for Jasper Schendelaar
# Fetching data for Sem Scheperman
# Fetching data for Gijs Smal
# Fetching data for Sven Sonnenberg
# Fetching data for Mark Spenkelink
# Fetching data for Calvin Stengs
# Fetching data for Anas Tahiri
# Fetching data for Kenneth Taylor
# Fetching data for Jordan Teze
# Fetching data for Ryan Thomas
# Fetching data for Mathijs Tielemans
# Fetching data for Quinten Timber
# Fetching data for Jens Toornstra
# Fetching data for Gernot Trauner
# Fetching data for Naci Unuvar
# Fetching data for Etienne Vaessen
# Fetching data for Jason Van Duiven
# Fetching data for Alec Van Hoorenbeeck
# Fetching data for Joey Veerman
# Fetching data for Calvin Verdonk
# Fetching data for Nick Viergever
# Fetching data for Siemen Voet
# Fetching data for Silvano Vos
# Fetching data for Charlie Webster
# Fetching data for Lasse Wehmeyer
# Fetching data for Timon Wellenreuther
# Fetching data for Mats Wieffer
# Fetching data for Jetro Willems
# Fetching data for Dani de Wit
# Fetching data for Redouan El Yaakoubi
# Fetching data for Ramiz Zerrouki

# %%
# Combine all DataFrames into one
combined_data = pd.concat(interest_data_frames, axis=1)

# Reset index to turn the index into a column
combined_data = combined_data.reset_index()

# Use melt to transform the data
melted_data = pd.melt(combined_data, id_vars=['date'], var_name='Player Name', value_name='Interest')

# %%
melted_data['Player Name'] = melted_data['Player Name'].str.replace('_', ' ')  # Adjust column names back to normal
melted_data['date'] = pd.to_datetime(melted_data['date'])
melted_data['Year'] = melted_data['date'].dt.year
melted_data['Week'] = melted_data['date'].dt.isocalendar().week

# %%
melted_data.to_csv('../../data/google-trends/missing_data_values.csv', index=False)
