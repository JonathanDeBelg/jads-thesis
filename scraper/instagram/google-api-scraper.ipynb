# %%
from googleapiclient.discovery import build
import pandas as pd

# Configuration variables
api_key = ''
cse_id = ''

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    if 'items' in res:
        return res['items'][0]['link']  # Return the first result's link
    return None

def find_instagram_url(player_name):
    query = f"{player_name} Instagram site:instagram.com"
    return google_search(query, api_key, cse_id, num=1)

# %%
data = pd.read_csv('data/football_data_with_instagram.csv')

# Find rows that are missing Instagram URLs
none_rows = data[data['instagram_url'].isna()]

for index, row in none_rows.iterrows():
    instagram_url = find_instagram_url(row['Name'])
    print(instagram_url)
    if instagram_url:
        data.at[index, 'instagram_url'] = instagram_url
# Out:
# None
# https://www.instagram.com/diegovanoorschot_/
# https://www.instagram.com/flipkl1/
# https://www.instagram.com/hansitomulder/
# https://www.instagram.com/lagaebram/
# https://www.instagram.com/mats_rots/
# https://www.instagram.com/mikehauptmeijer/
# https://www.instagram.com/p.kuiper38/
# https://www.instagram.com/sergirosanas/

# %%
data.to_csv('data/football_data_with_instagram.csv', index=False)

# %%
# Out:
#      Age              Team     ETV  Skill  Potential                 Name  \
# 0     20               PSV  €63.2M   70.6       85.0       Johan Bakayoko
# 1     28               PSV  €34.6M   78.1       78.9       Hirving Lozano
# 2     22         Feyenoord  €31.1M   69.8       78.8     Santiago Gimenez
# 3     22         Feyenoord  €29.8M   71.5       82.5  Quilindschy Hartman
# 4     23               PSV  €28.8M   72.7       81.2         Sergiño Dest
# ..   ...               ...     ...    ...        ...                  ...
# 441   23          Waalwijk    €80K   36.5       36.5       Ilias Takidine
# 442   18            Twente    €80K    0.0        0.0            Mats Rots
# 443   27        PEC Zwolle    €80K   43.8       43.8     Mike Hauptmeijer
# 444   20         Excelsior    €80K   42.8       42.8        Pascal Kuiper
# 445   23  Sparta Rotterdam    €70K   32.6       52.4        Sergi Rosanas
#
#            Position                               instagram_url
# 0          AM (CRL)    https://www.instagram.com/johanbakayoko/
# 1    AM (RL), M (R)    https://www.instagram.com/hirvinglozano/
# 2           A (CRL)     https://www.instagram.com/sant.gimenez/
# 3            V (CL)      https://www.instagram.com/quilindschy/
# 4    V (RL), AM (R)            https://www.instagram.com/sgd_2/
# ..              ...                                         ...
# 441        AM (CRL)        https://www.instagram.com/lagaebram/
# 442           V (C)        https://www.instagram.com/mats_rots/
# 443               K  https://www.instagram.com/mikehauptmeijer/
# 444               K       https://www.instagram.com/p.kuiper38/
# 445        M, V (R)     https://www.instagram.com/sergirosanas/
#
# [446 rows x 8 columns]
